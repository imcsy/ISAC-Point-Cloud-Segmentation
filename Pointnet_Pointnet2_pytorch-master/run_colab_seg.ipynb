# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# ## PointNet++ for Segmentation for S3DIS

# %%
# !python train_semseg.py --model pointnet2_sem_seg --log_dir pointnet2_sem_seg --epoch 10
# Out:
# PARAMETER ...
# Namespace(model='pointnet2_sem_seg', batch_size=16, epoch=10, learning_rate=0.001, gpu='0', optimizer='Adam', log_dir='pointnet2_sem_seg', decay_rate=0.0001, npoint=1024, step_size=10, lr_decay=0.7, samples_per_frame=4)
# start loading training data ...
# 100% 832/832 [00:29<00:00, 28.35it/s]
# [2.756257  1.        2.4621077 1.2294539]
# Totally 3328 samples in train set.
# start loading test data ...
# 100% 368/368 [00:01<00:00, 359.16it/s]
# [2.753397  1.        2.4692132 1.2299225]
# Totally 1472 samples in test set.
# The number of training data is: 3328
# The number of test data is: 1472
# No existing model, starting training from scratch...
# **** Epoch 1 (1/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:33<00:00,  2.23it/s]
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/train_semseg.py:206: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   log_string('Training mean loss: %f' % (loss_sum / num_batches))
# Training mean loss: 0.400735
# Training accuracy: 0.874466
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/model.pth
# Saving model....
# ---- EPOCH 001 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.42it/s]
# eval mean loss: 0.260198
# eval point avg class IoU: 0.785606
# eval point accuracy: 0.911059
# eval point avg class acc: 0.898663
# ------- IoU --------
# class car            weight: 0.326, IoU: 0.847
# class building       weight: 0.029, IoU: 0.876
# class pole           weight: 0.605, IoU: 0.619
# class clutter        weight: 0.040, IoU: 0.800
#
# Eval mean loss: 0.260198
# Eval accuracy: 0.911059
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/best_model.pth
# Saving model....
# Best mIoU: 0.785606
# **** Epoch 2 (2/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.29it/s]
# Training mean loss: 0.253788
# Training accuracy: 0.916720
# ---- EPOCH 002 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.39it/s]
# eval mean loss: 0.219424
# eval point avg class IoU: 0.829040
# eval point accuracy: 0.925229
# eval point avg class acc: 0.915666
# ------- IoU --------
# class car            weight: 0.325, IoU: 0.866
# class building       weight: 0.029, IoU: 0.896
# class pole           weight: 0.605, IoU: 0.739
# class clutter        weight: 0.040, IoU: 0.815
#
# Eval mean loss: 0.219424
# Eval accuracy: 0.925229
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/best_model.pth
# Saving model....
# Best mIoU: 0.829040
# **** Epoch 3 (3/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.31it/s]
# Training mean loss: 0.280328
# Training accuracy: 0.908477
# ---- EPOCH 003 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.42it/s]
# eval mean loss: 0.257512
# eval point avg class IoU: 0.809463
# eval point accuracy: 0.918796
# eval point avg class acc: 0.896022
# ------- IoU --------
# class car            weight: 0.325, IoU: 0.865
# class building       weight: 0.029, IoU: 0.887
# class pole           weight: 0.605, IoU: 0.679
# class clutter        weight: 0.040, IoU: 0.807
#
# Eval mean loss: 0.257512
# Eval accuracy: 0.918796
# Best mIoU: 0.829040
# **** Epoch 4 (4/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.30it/s]
# Training mean loss: 0.248766
# Training accuracy: 0.917410
# ---- EPOCH 004 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.40it/s]
# eval mean loss: 0.232182
# eval point avg class IoU: 0.813211
# eval point accuracy: 0.920605
# eval point avg class acc: 0.908088
# ------- IoU --------
# class car            weight: 0.325, IoU: 0.865
# class building       weight: 0.029, IoU: 0.890
# class pole           weight: 0.606, IoU: 0.689
# class clutter        weight: 0.040, IoU: 0.809
#
# Eval mean loss: 0.232182
# Eval accuracy: 0.920605
# Best mIoU: 0.829040
# **** Epoch 5 (5/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.30it/s]
# Training mean loss: 0.261009
# Training accuracy: 0.914410
# ---- EPOCH 005 EVALUATION ----
# 100% 92/92 [00:37<00:00,  2.43it/s]
# eval mean loss: 0.246121
# eval point avg class IoU: 0.810805
# eval point accuracy: 0.921426
# eval point avg class acc: 0.887565
# ------- IoU --------
# class car            weight: 0.325, IoU: 0.843
# class building       weight: 0.029, IoU: 0.891
# class pole           weight: 0.605, IoU: 0.700
# class clutter        weight: 0.040, IoU: 0.809
#
# Eval mean loss: 0.246121
# Eval accuracy: 0.921426
# Best mIoU: 0.829040
# **** Epoch 6 (6/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.30it/s]
# Training mean loss: 0.227443
# Training accuracy: 0.923487
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/model.pth
# Saving model....
# ---- EPOCH 006 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.41it/s]
# eval mean loss: 0.223276
# eval point avg class IoU: 0.809652
# eval point accuracy: 0.919030
# eval point avg class acc: 0.917976
# ------- IoU --------
# class car            weight: 0.325, IoU: 0.875
# class building       weight: 0.029, IoU: 0.886
# class pole           weight: 0.606, IoU: 0.663
# class clutter        weight: 0.040, IoU: 0.814
#
# Eval mean loss: 0.223276
# Eval accuracy: 0.919030
# Best mIoU: 0.829040
# **** Epoch 7 (7/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:29<00:00,  2.32it/s]
# Training mean loss: 0.216685
# Training accuracy: 0.926238
# ---- EPOCH 007 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.41it/s]
# eval mean loss: 0.205915
# eval point avg class IoU: 0.833190
# eval point accuracy: 0.927401
# eval point avg class acc: 0.922235
# ------- IoU --------
# class car            weight: 0.325, IoU: 0.864
# class building       weight: 0.029, IoU: 0.899
# class pole           weight: 0.605, IoU: 0.751
# class clutter        weight: 0.040, IoU: 0.819
#
# Eval mean loss: 0.205915
# Eval accuracy: 0.927401
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/best_model.pth
# Saving model....
# Best mIoU: 0.833190
# **** Epoch 8 (8/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.30it/s]
# Training mean loss: 0.217399
# Training accuracy: 0.925738
# ---- EPOCH 008 EVALUATION ----
# 100% 92/92 [00:39<00:00,  2.36it/s]
# eval mean loss: 0.589497
# eval point avg class IoU: 0.522220
# eval point accuracy: 0.835164
# eval point avg class acc: 0.579978
# ------- IoU --------
# class car            weight: 0.325, IoU: 0.589
# class building       weight: 0.029, IoU: 0.794
# class pole           weight: 0.606, IoU: 0.072
# class clutter        weight: 0.040, IoU: 0.634
#
# Eval mean loss: 0.589497
# Eval accuracy: 0.835164
# Best mIoU: 0.833190
# **** Epoch 9 (9/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:31<00:00,  2.28it/s]
# Training mean loss: 0.238712
# Training accuracy: 0.919530
# ---- EPOCH 009 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.38it/s]
# eval mean loss: 0.227999
# eval point avg class IoU: 0.805763
# eval point accuracy: 0.919640
# eval point avg class acc: 0.915902
# ------- IoU --------
# class car            weight: 0.325, IoU: 0.846
# class building       weight: 0.029, IoU: 0.888
# class pole           weight: 0.606, IoU: 0.676
# class clutter        weight: 0.040, IoU: 0.812
#
# Eval mean loss: 0.227999
# Eval accuracy: 0.919640
# Best mIoU: 0.833190
# **** Epoch 10 (10/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.31it/s]
# Training mean loss: 0.214676
# Training accuracy: 0.926293
# ---- EPOCH 010 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.38it/s]
# eval mean loss: 0.477455
# eval point avg class IoU: 0.627360
# eval point accuracy: 0.802584
# eval point avg class acc: 0.725051
# ------- IoU --------
# class car            weight: 0.325, IoU: 0.786
# class building       weight: 0.029, IoU: 0.760
# class pole           weight: 0.605, IoU: 0.493
# class clutter        weight: 0.040, IoU: 0.470
#
# Eval mean loss: 0.477455
# Eval accuracy: 0.802584
# Best mIoU: 0.833190

# %%
# !python test_semseg.py --log_dir pointnet2_sem_seg --visual
# Out:
# PARAMETER ...
# Namespace(batch_size=32, gpu='0', num_point=1024, log_dir='pointnet2_sem_seg', visual=True, num_votes=3, samples_per_frame=4)
# 100% 368/368 [00:06<00:00, 60.86it/s]
# [2.753397  1.        2.4692132 1.2299225]
# Totally 1472 samples in test set.
# The number of test data is: 1472
# ---- EVALUATION WHOLE SCENE----
# 100% 46/46 [00:35<00:00,  1.28it/s]
# eval point avg class IoU: 0.837334
# eval point accuracy: 0.928761
# eval point avg class acc: 0.922797
# ------- IoU --------
# class car           , IoU: 0.871
# class building      , IoU: 0.901
# class pole          , IoU: 0.756
# class clutter       , IoU: 0.822
#
# eval point avg class IoU: 0.837334
# eval whole scene point avg class acc: 0.922797
# eval whole scene point accuracy: 0.928761
# Done!
