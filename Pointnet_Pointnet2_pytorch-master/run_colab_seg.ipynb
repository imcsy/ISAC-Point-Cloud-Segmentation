# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %%
# Confirm current directory
# %ls
# Out:
# data/        provider.py          test_classification.py   train_semseg.py
# data_utils/  __pycache__/         test_partseg.py          visualizer/
# LICENSE      README.md            test_semseg.py
# log/         run_colab_cls.ipynb  train_classification.py
# models/      run_colab_seg.ipynb  train_partseg.py

# %% [markdown]
# ## Data Preprocessing

# %%
# %cd data_utils/
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/data_utils

# %%
# %ls
# Out:
# collect_indoor3d_data.py  ModelNetDataLoader.py  ShapeNetDataLoader.py
# indoor3d_util.py          __pycache__/
# meta/                     S3DISDataLoader.py

# %%
# !python collect_indoor3d_data.py
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/data/s3dis/Stanford3dDataset_v1.2_Aligned_Version/Area_1/conferenceRoom_1/Annotations
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/data/s3dis/Stanford3dDataset_v1.2_Aligned_Version/Area_1/conferenceRoom_1/Annotations ERROR!!
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/data/s3dis/Stanford3dDataset_v1.2_Aligned_Version/Area_1/conferenceRoom_2/Annotations
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/data/s3dis/Stanford3dDataset_v1.2_Aligned_Version/Area_1/conferenceRoom_2/Annotations/chair_13.txt
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/data/s3dis/Stanford3dDataset_v1.2_Aligned_Version/Area_1/conferenceRoom_2/Annotations/ceiling_1.txt
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/data/s3dis/Stanford3dDataset_v1.2_Aligned_Version/Area_1/conferenceRoom_2/Annotations/chair_12.txt
# ^C

# %% [markdown]
# ## PointNet++ for Segmentation for S3DIS

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %%
# !python train_semseg.py --model pointnet2_sem_seg --test_area 3 --log_dir pointnet2_sem_seg --epoch 1
# Out:
# PARAMETER ...
# Namespace(model='pointnet2_sem_seg', batch_size=16, epoch=1, learning_rate=0.001, gpu='0', optimizer='Adam', log_dir='pointnet2_sem_seg', decay_rate=0.0001, npoint=4096, step_size=10, lr_decay=0.7, test_area=3)
# start loading training data ...
# 100% 83/83 [01:38<00:00,  1.18s/it]
# [1.0930161 1.1452146 1.        2.1247208 2.4215431 2.4236634 1.7099016
#  2.170585  1.717748  4.1906533 1.8649924 2.7096317 1.3303537]
# Totally 22024 samples in train set.
# start loading test data ...
# 100% 23/23 [00:15<00:00,  1.50it/s]
# [1.116343  1.1947311 1.        2.4383423 2.4463546 2.4935763 1.8087621
#  2.105977  2.2112877 3.0018995 1.5890619 2.6210735 1.3362237]
# Totally 4558 samples in test set.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# The number of training data is: 22024
# The number of test data is: 4558
# No existing model, starting training from scratch...
# **** Epoch 1 (1/1) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 100% 1376/1376 [26:33<00:00,  1.16s/it]
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/train_semseg.py:204: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   log_string('Training mean loss: %f' % (loss_sum / num_batches))
# Training mean loss: 0.949454
# Training accuracy: 0.734766
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/model.pth
# Saving model....
# ---- EPOCH 001 EVALUATION ----
# 100% 284/284 [03:36<00:00,  1.31it/s]
# eval mean loss: 0.898787
# eval point avg class IoU: 0.426538
# eval point accuracy: 0.738758
# eval point avg class acc: 0.564970
# ------- IoU --------
# class ceiling        weight: 0.116, IoU: 0.877
# class floor          weight: 0.204, IoU: 0.936
# class wall           weight: 0.165, IoU: 0.621
# class beam           weight: 0.260, IoU: 0.346
# class column         weight: 0.022, IoU: 0.099
# class window         weight: 0.018, IoU: 0.132
# class door           weight: 0.017, IoU: 0.479
# class table          weight: 0.045, IoU: 0.516
# class chair          weight: 0.032, IoU: 0.537
# class sofa           weight: 0.027, IoU: 0.149
# class bookcase       weight: 0.011, IoU: 0.338
# class board          weight: 0.068, IoU: 0.272
# class clutter        weight: 0.013, IoU: 0.244
#
# Eval mean loss: 0.898787
# Eval accuracy: 0.738758
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/best_model.pth
# Saving model....
# Best mIoU: 0.426538
