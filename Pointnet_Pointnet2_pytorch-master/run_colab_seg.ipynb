# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# ## PointNet++ for Segmentation for S3DIS

# %%
# !python train_semseg.py --model pointnet2_sem_seg --log_dir pointnet2_sem_seg --epoch 10
# Out:
# PARAMETER ...
# Namespace(model='pointnet2_sem_seg', batch_size=16, epoch=10, learning_rate=0.001, gpu='0', optimizer='Adam', log_dir='pointnet2_sem_seg', decay_rate=0.0001, npoint=1024, step_size=10, lr_decay=0.7, samples_per_frame=4)
# start loading training data ...
# 100% 832/832 [00:01<00:00, 427.96it/s]
# [3.457756  1.        2.4621077 1.212011 ]
# Totally 3328 samples in train set.
# start loading test data ...
# 100% 368/368 [00:00<00:00, 403.14it/s]
# [3.4682746 1.        2.4692132 1.2121884]
# Totally 1472 samples in test set.
# The number of training data is: 3328
# The number of test data is: 1472
# No existing model, starting training from scratch...
# **** Epoch 1 (1/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:31<00:00,  2.27it/s]
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/train_semseg.py:206: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   log_string('Training mean loss: %f' % (loss_sum / num_batches))
# Training mean loss: 0.402398
# Training accuracy: 0.877754
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/model.pth
# Saving model....
# ---- EPOCH 001 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.41it/s]
# eval mean loss: 0.300502
# eval point avg class IoU: 0.662627
# eval point accuracy: 0.894580
# eval point avg class acc: 0.874407
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.481
# class building       weight: 0.014, IoU: 0.859
# class pole           weight: 0.606, IoU: 0.509
# class clutter        weight: 0.040, IoU: 0.802
#
# Eval mean loss: 0.300502
# Eval accuracy: 0.894580
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/best_model.pth
# Saving model....
# Best mIoU: 0.662627
# **** Epoch 2 (2/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.29it/s]
# Training mean loss: 0.269742
# Training accuracy: 0.911876
# ---- EPOCH 002 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.40it/s]
# eval mean loss: 0.287219
# eval point avg class IoU: 0.698144
# eval point accuracy: 0.898575
# eval point avg class acc: 0.858293
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.613
# class building       weight: 0.015, IoU: 0.862
# class pole           weight: 0.606, IoU: 0.523
# class clutter        weight: 0.040, IoU: 0.795
#
# Eval mean loss: 0.287219
# Eval accuracy: 0.898575
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/best_model.pth
# Saving model....
# Best mIoU: 0.698144
# **** Epoch 3 (3/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.29it/s]
# Training mean loss: 0.259301
# Training accuracy: 0.913383
# ---- EPOCH 003 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.39it/s]
# eval mean loss: 0.231974
# eval point avg class IoU: 0.754133
# eval point accuracy: 0.919715
# eval point avg class acc: 0.891834
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.594
# class building       weight: 0.015, IoU: 0.894
# class pole           weight: 0.605, IoU: 0.718
# class clutter        weight: 0.040, IoU: 0.811
#
# Eval mean loss: 0.231974
# Eval accuracy: 0.919715
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/best_model.pth
# Saving model....
# Best mIoU: 0.754133
# **** Epoch 4 (4/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:31<00:00,  2.28it/s]
# Training mean loss: 0.223737
# Training accuracy: 0.924513
# ---- EPOCH 004 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.40it/s]
# eval mean loss: 0.213892
# eval point avg class IoU: 0.768471
# eval point accuracy: 0.922670
# eval point avg class acc: 0.916935
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.624
# class building       weight: 0.014, IoU: 0.897
# class pole           weight: 0.606, IoU: 0.736
# class clutter        weight: 0.040, IoU: 0.817
#
# Eval mean loss: 0.213892
# Eval accuracy: 0.922670
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/best_model.pth
# Saving model....
# Best mIoU: 0.768471
# **** Epoch 5 (5/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.29it/s]
# Training mean loss: 0.221850
# Training accuracy: 0.924869
# ---- EPOCH 005 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.40it/s]
# eval mean loss: 0.280757
# eval point avg class IoU: 0.746448
# eval point accuracy: 0.915301
# eval point avg class acc: 0.833945
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.668
# class building       weight: 0.014, IoU: 0.886
# class pole           weight: 0.605, IoU: 0.632
# class clutter        weight: 0.040, IoU: 0.800
#
# Eval mean loss: 0.280757
# Eval accuracy: 0.915301
# Best mIoU: 0.768471
# **** Epoch 6 (6/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.29it/s]
# Training mean loss: 0.209507
# Training accuracy: 0.928282
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/model.pth
# Saving model....
# ---- EPOCH 006 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.39it/s]
# eval mean loss: 0.209729
# eval point avg class IoU: 0.794801
# eval point accuracy: 0.928406
# eval point avg class acc: 0.904931
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.680
# class building       weight: 0.014, IoU: 0.903
# class pole           weight: 0.605, IoU: 0.772
# class clutter        weight: 0.040, IoU: 0.824
#
# Eval mean loss: 0.209729
# Eval accuracy: 0.928406
# Saving at log/sem_seg/pointnet2_sem_seg/checkpoints/best_model.pth
# Saving model....
# Best mIoU: 0.794801
# **** Epoch 7 (7/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:31<00:00,  2.28it/s]
# Training mean loss: 0.271588
# Training accuracy: 0.909071
# ---- EPOCH 007 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.38it/s]
# eval mean loss: 0.242151
# eval point avg class IoU: 0.740428
# eval point accuracy: 0.913263
# eval point avg class acc: 0.903122
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.635
# class building       weight: 0.015, IoU: 0.882
# class pole           weight: 0.605, IoU: 0.630
# class clutter        weight: 0.040, IoU: 0.814
#
# Eval mean loss: 0.242151
# Eval accuracy: 0.913263
# Best mIoU: 0.794801
# **** Epoch 8 (8/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.29it/s]
# Training mean loss: 0.240417
# Training accuracy: 0.918880
# ---- EPOCH 008 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.39it/s]
# eval mean loss: 0.222353
# eval point avg class IoU: 0.768614
# eval point accuracy: 0.922177
# eval point avg class acc: 0.900995
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.635
# class building       weight: 0.014, IoU: 0.895
# class pole           weight: 0.605, IoU: 0.728
# class clutter        weight: 0.040, IoU: 0.817
#
# Eval mean loss: 0.222353
# Eval accuracy: 0.922177
# Best mIoU: 0.794801
# **** Epoch 9 (9/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:30<00:00,  2.30it/s]
# Training mean loss: 0.291919
# Training accuracy: 0.903906
# ---- EPOCH 009 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.38it/s]
# eval mean loss: 0.250344
# eval point avg class IoU: 0.746778
# eval point accuracy: 0.914577
# eval point avg class acc: 0.879633
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.636
# class building       weight: 0.015, IoU: 0.885
# class pole           weight: 0.605, IoU: 0.659
# class clutter        weight: 0.040, IoU: 0.808
#
# Eval mean loss: 0.250344
# Eval accuracy: 0.914577
# Best mIoU: 0.794801
# **** Epoch 10 (10/10) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 208/208 [01:31<00:00,  2.26it/s]
# Training mean loss: 0.246239
# Training accuracy: 0.916913
# ---- EPOCH 010 EVALUATION ----
# 100% 92/92 [00:38<00:00,  2.40it/s]
# eval mean loss: 0.247548
# eval point avg class IoU: 0.731841
# eval point accuracy: 0.912378
# eval point avg class acc: 0.893447
# ------- IoU --------
# class car            weight: 0.340, IoU: 0.609
# class building       weight: 0.015, IoU: 0.882
# class pole           weight: 0.605, IoU: 0.625
# class clutter        weight: 0.040, IoU: 0.811
#
# Eval mean loss: 0.247548
# Eval accuracy: 0.912378
# Best mIoU: 0.794801

# %%
# !python test_semseg.py --log_dir pointnet2_sem_seg --visual
# Out:
# PARAMETER ...
# Namespace(batch_size=32, gpu='0', num_point=1024, log_dir='pointnet2_sem_seg', visual=True, num_votes=3, samples_per_frame=4)
# 100% 368/368 [00:06<00:00, 60.64it/s]
# [3.4682746 1.        2.4692132 1.2121884]
# Totally 1472 samples in test set.
# The number of test data is: 1472
# ---- EVALUATION WHOLE SCENE----
# 100% 46/46 [00:20<00:00,  2.27it/s]
# eval point avg class IoU: 0.797605
# eval point accuracy: 0.928230
# eval point avg class acc: 0.904961
# ------- IoU --------
# class car           , IoU: 0.686
# class building      , IoU: 0.903
# class pole          , IoU: 0.780
# class clutter       , IoU: 0.822
#
# eval point avg class IoU: 0.797605
# eval whole scene point avg class acc: 0.904961
# eval whole scene point accuracy: 0.928230
# Done!
