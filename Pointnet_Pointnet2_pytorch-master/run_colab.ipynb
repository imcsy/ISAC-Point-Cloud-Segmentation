# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %%
# Confirm current directory
# %ls
# Out:
# data_utils/  provider.py      test_classification.py   train_partseg.py
# LICENSE      __pycache__/     test_partseg.py          train_semseg.py
# log/         README.md        test_semseg.py           visualizer/
# models/      run_colab.ipynb  train_classification.py

# %% [markdown]
# ## PointNet for classification on ModelNet10

# %%
# !python train_classification.py --model pointnet_cls --log_dir pointnet_cls --epoch 5 --num_category 10
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, model='pointnet_cls', num_category=10, epoch=5, learning_rate=0.001, num_point=1024, optimizer='Adam', log_dir='pointnet_cls', decay_rate=0.0001, use_normals=False, process_data=False, use_uniform_sample=False)
# Load dataset ...
# The size of train data is 3991
# The size of test data is 908
# No existing model, starting training from scratch...
# Epoch 1 (1/5):
# 100% 166/166 [00:48<00:00,  3.44it/s]
# Train Instance Accuracy: 0.656627
# 100% 38/38 [00:11<00:00,  3.43it/s]
# Test Instance Accuracy: 0.614912, Class Accuracy: 0.560863
# Best Instance Accuracy: 0.614912, Class Accuracy: 0.560863
# Saving at log/classification/pointnet_cls/checkpoints/best_model.pth
# Epoch 2 (2/5):
# 100% 166/166 [00:49<00:00,  3.32it/s]
# Train Instance Accuracy: 0.789910
# 100% 38/38 [00:11<00:00,  3.22it/s]
# Test Instance Accuracy: 0.526535, Class Accuracy: 0.481716
# Best Instance Accuracy: 0.614912, Class Accuracy: 0.560863
# ...

# %%
# !python test_classification.py --log_dir pointnet_cls --num_category 10
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, num_category=10, num_point=1024, log_dir='pointnet_cls', use_normals=False, use_uniform_sample=False, num_votes=3)
# Load dataset ...
# The size of test data is 908
# 100% 38/38 [00:12<00:00,  3.05it/s]
# Test Instance Accuracy: 0.835526, Class Accuracy: 0.826438

# %% [markdown]
# ## PointNet++ for classification on ModelNet10

# %%
# !python train_classification.py --model pointnet2_cls_ssg --log_dir pointnet2_cls_ssg --epoch 5 --num_category 10
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, model='pointnet2_cls_ssg', num_category=10, epoch=5, learning_rate=0.001, num_point=1024, optimizer='Adam', log_dir='pointnet2_cls_ssg', decay_rate=0.0001, use_normals=False, process_data=False, use_uniform_sample=False)
# Load dataset ...
# The size of train data is 3991
# The size of test data is 908
# No existing model, starting training from scratch...
# Epoch 1 (1/5):
# 100% 166/166 [01:24<00:00,  1.97it/s]
# Train Instance Accuracy: 0.732179
# 100% 38/38 [00:18<00:00,  2.00it/s]
# Test Instance Accuracy: 0.725658, Class Accuracy: 0.670847
# Best Instance Accuracy: 0.725658, Class Accuracy: 0.670847
# Saving at log/classification/pointnet2_cls_ssg/checkpoints/best_model.pth
# Epoch 2 (2/5):
# 100% 166/166 [01:24<00:00,  1.96it/s]
# Train Instance Accuracy: 0.836847
# 100% 38/38 [00:20<00:00,  1.87it/s]
# Test Instance Accuracy: 0.814693, Class Accuracy: 0.798788
# ...

# %%
# !python test_classification.py --log_dir pointnet2_cls_ssg --num_category 10
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, num_category=10, num_point=1024, log_dir='pointnet2_cls_ssg', use_normals=False, use_uniform_sample=False, num_votes=3)
# Load dataset ...
# The size of test data is 908
# 100% 38/38 [00:36<00:00,  1.05it/s]
# Test Instance Accuracy: 0.843860, Class Accuracy: 0.834482

# %% [markdown]
# ## Try PointNet for classification on ModelNet2 (customize)

# %%
# !python train_classification.py --model pointnet_cls --log_dir pointnet_cls --epoch 5 --num_category 2 --num_channel 4 --num_point 512
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, model='pointnet_cls', num_category=2, epoch=5, learning_rate=0.001, num_point=512, optimizer='Adam', log_dir='pointnet_cls', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False)
# Load dataset ...
# The size of train data is 732
# The size of test data is 150
# Epoch 1 (1/5):
# 100% 30/30 [02:43<00:00,  5.45s/it]
# Train Instance Accuracy: 0.929167
# 100% 7/7 [00:38<00:00,  5.55s/it]
# Test Instance Accuracy: 0.595238, Class Accuracy: 0.500000
# Best Instance Accuracy: 0.595238, Class Accuracy: 0.500000
# Saving at log/classification/pointnet_cls/checkpoints/best_model.pth
# Epoch 2 (2/5):
# 100% 30/30 [02:24<00:00,  4.83s/it]
# Train Instance Accuracy: 0.969444
# 100% 7/7 [00:29<00:00,  4.20s/it]
# Test Instance Accuracy: 0.982143, Class Accuracy: 0.966667
# Best Instance Accuracy: 0.982143, Class Accuracy: 0.966667
# Saving at log/classification/pointnet_cls/checkpoints/best_model.pth
# ...

# %%
# !python test_classification.py --log_dir pointnet_cls --num_category 2 --num_channel 4 --num_point 512
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, num_category=2, num_point=512, log_dir='pointnet_cls', num_channel=4, use_uniform_sample=False, num_votes=3)
# Load dataset ...
# The size of test data is 150
# 100% 7/7 [00:30<00:00,  4.35s/it]
# Test Instance Accuracy: 0.994048, Class Accuracy: 0.995833

# %% [markdown]
# ## Try PointNet for classification on MyModelNet2 (car & clutter)

# %%
# !python train_classification.py --model pointnet_cls --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --epoch 5 --num_point 8
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, model='pointnet_cls', num_category=2, epoch=5, learning_rate=0.001, num_point=8, optimizer='Adam', log_dir='pointnet_cls_mymodelnet', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False, dropout=False, shift=False)
# Load dataset ...
# The size of train data is 5734
# The size of test data is 2458
# Epoch 1 (1/5):
# 100% 238/238 [00:16<00:00, 14.12it/s]
# Train Instance Accuracy: 0.881303
# 100% 103/103 [00:07<00:00, 14.51it/s]
# Test Instance Accuracy: 0.932686, Class Accuracy: 0.934509
# Best Instance Accuracy: 0.932686, Class Accuracy: 0.934509
# Saving at log/classification/pointnet_cls_mymodelnet/epoch_5_npoint_8/checkpoints/best_model.pth
# Epoch 2 (2/5):
# 100% 238/238 [00:16<00:00, 14.53it/s]
# Train Instance Accuracy: 0.915441
# 100% 103/103 [00:06<00:00, 16.84it/s]
# Test Instance Accuracy: 0.902751, Class Accuracy: 0.902908
# ...

# %%
# !python test_classification.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --num_point 8 --epoch 5 --num_point 8
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=5, num_point=8)
# Load dataset ...
# The size of test data is 2458
# 100% 103/103 [00:06<00:00, 16.52it/s]
# Test Instance Accuracy: 0.946278, Class Accuracy: 0.950658
