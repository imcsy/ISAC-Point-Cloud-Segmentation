# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# # Train PointGuard for Segmnetation (with mix of perturbation and injected samples)

# %%
# !python train_pointguard_seg.py --model pointnet_pointguard --log_dir pointguard_segmentation_mix
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=16, model='pointnet_pointguard', epoch=10, learning_rate=0.001, num_point=1024, optimizer='Adam', log_dir='pointguard_segmentation_mix', decay_rate=0.0001, num_channel=4, per_prob=0.4, inject_prob=0.4, channels_per=[0, 1, 2, 3], eps_per=1.5)
# Load dataset ...
# 100% 832/832 [00:10<00:00, 80.23it/s]
# Totally 3328 samples in train set.
# 100% 368/368 [00:01<00:00, 278.76it/s]
# Totally 1472 samples in test set.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Epoch 1 (1/10):
# ...
