# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# ## Try PointNet for classification on MyModelNet2 (car & clutter)

# %%
# !python train_classification.py --model pointnet_cls --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16 --dropout --shift
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_cls', num_category=2, epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointnet_cls_mymodelnet', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False, dropout=True, shift=True)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/10):
# 100% 146/146 [04:40<00:00,  1.92s/it]
# Train Instance Accuracy: 0.920163
# 100% 63/63 [02:30<00:00,  2.39s/it]
# Test Instance Accuracy: 0.957011, Class Accuracy: 0.956945
# Best Instance Accuracy: 0.957011, Class Accuracy: 0.956945
# Saving at log/classification/pointnet_cls_mymodelnet/epoch_10_npoint_16_bsize_64_dropout_shift/checkpoints/best_model.pth
# Epoch 2 (2/10):
# 100% 146/146 [00:21<00:00,  6.67it/s]
# Train Instance Accuracy: 0.945098
# 100% 63/63 [00:09<00:00,  6.98it/s]
# Test Instance Accuracy: 0.918981, Class Accuracy: 0.921718
# ...

# %%
# !python test_classification.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16 --dropout --shift
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=True, shift=True, epoch=10, num_point=16)
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:09<00:00,  6.78it/s]
# Test Instance Accuracy: 0.967593, Class Accuracy: 0.968135

# %% [markdown]
# # **Training**

# %%
# NoiseTrain
# !python train_classification.py --model pointnet_cls --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16 --dropout --shift
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_cls', num_category=2, epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointnet_cls_mymodelnet', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False, dropout=True, shift=True)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/10):
# 100% 146/146 [00:21<00:00,  6.88it/s]
# Train Instance Accuracy: 0.926156
# 100% 63/63 [00:08<00:00,  7.30it/s]
# Test Instance Accuracy: 0.949735, Class Accuracy: 0.948548
# Best Instance Accuracy: 0.949735, Class Accuracy: 0.948548
# Saving at log/classification/pointnet_cls_mymodelnet/epoch_10_npoint_16_bsize_64_dropout_shift/checkpoints/best_model.pth
# Epoch 2 (2/10):
# 100% 146/146 [00:22<00:00,  6.61it/s]
# Train Instance Accuracy: 0.943386
# 100% 63/63 [00:09<00:00,  6.78it/s]
# Test Instance Accuracy: 0.951472, Class Accuracy: 0.952501
# ...

# %%
# AdvTrain
# !python train_classification_AdvTrain.py --model pointnet_cls --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 5 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_cls', num_category=2, epoch=5, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointnet_cls_mymodelnet', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False, per_prob=0.3, inject_prob=0.3, npoints_inj=2, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=0.5)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/5):
# 100% 146/146 [00:25<00:00,  5.64it/s]
# Train Instance Accuracy: 0.917915
# 100% 63/63 [00:10<00:00,  6.20it/s]
# Test Instance Accuracy: 0.946759, Class Accuracy: 0.946681
# Best Instance Accuracy: 0.946759, Class Accuracy: 0.946681
# Saving at log/classification/pointnet_cls_mymodelnet/AdvTrain_epoch_5_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 2 (2/5):
# 100% 146/146 [00:24<00:00,  6.05it/s]
# Train Instance Accuracy: 0.938998
# 100% 63/63 [00:10<00:00,  5.77it/s]
# ...

# %% [markdown]
# # **Perturbation Attacks (eps)**

# %% [markdown]
# ## Test Vanilla Models under  Attacks

# %% [markdown]
# no dropout and shift

# %%
# !python train_classification.py --model pointnet_cls --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_cls', num_category=2, epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointnet_cls_mymodelnet', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False, dropout=False, shift=False)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/10):
# 100% 146/146 [06:07<00:00,  2.52s/it]
# Train Instance Accuracy: 0.928189
# 100% 63/63 [02:42<00:00,  2.57s/it]
# Test Instance Accuracy: 0.952960, Class Accuracy: 0.953841
# Best Instance Accuracy: 0.952960, Class Accuracy: 0.953841
# Saving at log/classification/pointnet_cls_mymodelnet/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 2 (2/10):
# 100% 146/146 [00:22<00:00,  6.53it/s]
# Train Instance Accuracy: 0.948951
# 100% 63/63 [00:08<00:00,  7.60it/s]
# Test Instance Accuracy: 0.953290, Class Accuracy: 0.952952
# ...

# %%
# !python test_classification_per_attack.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# Streaming output truncated to the last 5000 lines.
# tensor([0.7810, 0.6512, 0.3365, 4.6451], device='cuda:0')
# tensor([0.6719, 0.6240, 0.3278, 4.7285], device='cuda:0')
# tensor([0.7523, 0.5730, 0.3457, 4.6888], device='cuda:0')
#  41% 26/63 [00:04<00:04,  7.62it/s]tensor([0.7201, 0.6596, 0.3416, 4.2057], device='cuda:0')
# tensor([0.7260, 0.6126, 0.3326, 4.3310], device='cuda:0')
# tensor([0.8322, 0.5503, 0.3355, 4.2440], device='cuda:0')
# tensor([0.6868, 0.7029, 0.3572, 2.7920], device='cuda:0')
#  48% 30/63 [00:04<00:03, 10.22it/s]tensor([1.0205, 0.8986, 0.4330, 1.0775], device='cuda:0')
# tensor([0.7222, 0.9385, 0.4589, 0.8420], device='cuda:0')
# tensor([0.8312, 0.8715, 0.4549, 0.5607], device='cuda:0')
#  52% 33/63 [00:05<00:05,  5.96it/s]tensor([0.8494, 0.8993, 0.5498, 0.9652], device='cuda:0')
# tensor([0.6317, 0.7495, 0.5116, 1.3134], device='cuda:0')
# tensor([0.8724, 0.8793, 0.5280, 0.1914], device='cuda:0')
# ...

# %% [markdown]
# ## Test Baseline Models under Attacks

# %% [markdown]
# with dropout and shift

# %%
# !python test_classification_per_attack.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16 --dropout --shift
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=True, shift=True, epoch=10, num_point=16)
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:11<00:00,  5.62it/s]
# Perturbation channels: [0, 1, 2], Perturbation epsilon: 0.000000
# Test Instance Accuracy: 0.965856, Class Accuracy: 0.966625
# 100% 63/63 [00:10<00:00,  6.12it/s]
# Perturbation channels: [3], Perturbation epsilon: 0.000000
# Test Instance Accuracy: 0.965856, Class Accuracy: 0.966625
# 100% 63/63 [00:09<00:00,  6.41it/s]
# Perturbation channels: [0, 1, 2, 3], Perturbation epsilon: 0.000000
# Test Instance Accuracy: 0.965856, Class Accuracy: 0.966625
# 100% 63/63 [00:10<00:00,  5.74it/s]
# Perturbation channels: [0, 1, 2], Perturbation epsilon: 0.100000
# Test Instance Accuracy: 0.958416, Class Accuracy: 0.959823
# 100% 63/63 [00:10<00:00,  6.08it/s]
# ...

# %% [markdown]
# ## Defense without PointGuard Network

# %% [markdown]
# calculate score directly

# %%
# !python train_classification_defense.py --model pointnet_cls --log_dir pointnet_cls_mymodelnet_defense --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_cls', num_category=2, epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointnet_cls_mymodelnet_defense', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/10):
# 100% 146/146 [13:34<00:00,  5.58s/it]
# Train Instance Accuracy for clean data: 0.930651
# Train Instance Accuracy for pertuebed data: 0.844499
# 100% 63/63 [06:19<00:00,  6.03s/it]
# Test Instance Accuracy for clean data: 0.942874, Class Accuracy for clean data: 0.941455
# Best Instance Accuracy for clean data: 0.942874, Class Accuracy for clean data: 0.941455
# Saving at log/classification/pointnet_cls_mymodelnet_defense/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 2 (2/10):
# 100% 146/146 [00:37<00:00,  3.90it/s]
# Train Instance Accuracy for clean data: 0.950235
# ...

# %%
# !python test_classification_defense_noADnet.py --log_dir pointnet_cls_mymodelnet_defense --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet_defense', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=10, num_point=16)
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:15<00:00,  3.95it/s]
# Perturbation channels: [1, 3], Perturbation epsilon: 4.000000
# Test Instance Accuracy: 0.931878, Class Accuracy: 0.933419

# %% [markdown]
# ## Defense with PointGuard Network

# %% [markdown]
# use PointGuard to calculate scores

# %%
# !python test_classification_defense_PointGuard.py --log_dir pointnet_cls_mymodelnet_defense --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet_defense', num_channel=4, use_uniform_sample=False, num_votes=1, dropout=False, shift=False, epoch=10, num_point=16)
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [02:38<00:00,  2.52s/it]
# Perturbation channels: [0, 1, 2], Perturbation epsilon: 0.000000
# Test Instance Accuracy: 0.936425, Class Accuracy: 0.934562
# 100% 63/63 [00:09<00:00,  6.64it/s]
# Perturbation channels: [3], Perturbation epsilon: 0.000000
# Test Instance Accuracy: 0.936425, Class Accuracy: 0.934562
# 100% 63/63 [00:09<00:00,  6.90it/s]
# Perturbation channels: [0, 1, 2, 3], Perturbation epsilon: 0.000000
# Test Instance Accuracy: 0.936425, Class Accuracy: 0.934562
# 100% 63/63 [00:08<00:00,  7.45it/s]
# Perturbation channels: [0, 1, 2], Perturbation epsilon: 0.100000
# Test Instance Accuracy: 0.942295, Class Accuracy: 0.940889
# 100% 63/63 [00:09<00:00,  6.53it/s]
# ...

# %% [markdown]
# # **Perturbation Attacks (cd)**

# %% [markdown]
# Test each model under mix of samples. PointGuard use new arhictecture

# %%
# vanilla
# !python test_classification_per_attack_cd.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16 --eps_per 1 --num_runs 5
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=10, num_point=16, npoints_inj=3, clutter_size_inj=1, channels_per=[0, 1, 2, 3], eps_per=1.0, num_runs=5, is_PointGuard=False, AdvTrain=False)
# Load dataset ...
# The size of test data is 4016
# 5  runs in total
# 100% 63/63 [00:10<00:00,  6.06it/s]
# TP: 1835 FN 46 FP 542 TN 1593
# 100% 63/63 [00:09<00:00,  6.60it/s]
# TP: 1817 FN 64 FP 485 TN 1650
# 100% 63/63 [00:10<00:00,  6.02it/s]
# TP: 1818 FN 63 FP 517 TN 1618
# 100% 63/63 [00:10<00:00,  6.16it/s]
# TP: 1821 FN 60 FP 490 TN 1645
# 100% 63/63 [00:09<00:00,  6.77it/s]
# TP: 1828 FN 53 FP 521 TN 1614

# %%
# NoiseTrain
# !python test_classification_per_attack_cd.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16 --eps_per 1 --num_runs 5 --dropout --shift
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=True, shift=True, epoch=10, num_point=16, npoints_inj=3, clutter_size_inj=1, channels_per=[0, 1, 2, 3], eps_per=1.0, num_runs=5, is_PointGuard=False, AdvTrain=False)
# Load dataset ...
# The size of test data is 4016
# 5  runs in total
# 100% 63/63 [00:10<00:00,  6.06it/s]
# TP: 1789 FN 92 FP 259 TN 1876
# 100% 63/63 [00:09<00:00,  6.32it/s]
# TP: 1801 FN 80 FP 272 TN 1863
# 100% 63/63 [00:09<00:00,  6.98it/s]
# TP: 1801 FN 80 FP 258 TN 1877
# 100% 63/63 [00:10<00:00,  6.17it/s]
# TP: 1799 FN 82 FP 260 TN 1875
# 100% 63/63 [00:10<00:00,  6.12it/s]
# TP: 1793 FN 88 FP 252 TN 1883

# %%
# AdvTrain
# !python test_classification_per_attack_cd.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 5 --num_point 16 --eps_per 1 --num_runs 10 --AdvTrain
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=5, num_point=16, npoints_inj=0, clutter_size_inj=0, channels_per=[0, 1, 2, 3], eps_per=1.0, num_runs=10, is_PointGuard=False, AdvTrain=True)
# Load dataset ...
# The size of test data is 4016
# 10  runs in total
# 100% 63/63 [00:09<00:00,  6.45it/s]
# 100% 63/63 [00:10<00:00,  6.18it/s]
# 100% 63/63 [00:10<00:00,  6.23it/s]
# 100% 63/63 [00:09<00:00,  6.84it/s]
# 100% 63/63 [00:10<00:00,  6.24it/s]
# 100% 63/63 [00:10<00:00,  6.07it/s]
# 100% 63/63 [00:09<00:00,  6.55it/s]
# 100% 63/63 [00:09<00:00,  6.32it/s]
# 100% 63/63 [00:10<00:00,  6.19it/s]
# 100% 63/63 [00:10<00:00,  6.25it/s]
# Data saved to log/classification/pointnet_cls_mymodelnet/AdvTrain_epoch_5_npoint_16_bsize_64//per_attack_comparison_channel_[0, 1, 2, 3]_eps_1.0.csv

# %%
# PointGuard
# !python test_classification_per_attack_cd.py --log_dir pointnet_cls_mymodelnet_defense --num_category 2 --num_channel 4 --batch_size 32 --epoch 10 --num_point 16 --eps_per 1 --num_runs 5 --is_PointGuard
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=32, num_category=2, log_dir='pointnet_cls_mymodelnet_defense', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=10, num_point=16, npoints_inj=3, clutter_size_inj=1, channels_per=[0, 1, 2, 3], eps_per=1.0, num_runs=5, is_PointGuard=True, AdvTrain=False)
# Load dataset ...
# The size of test data is 4016
# model: pointnet_cls_pointguard
# 5  runs in total
# 100% 126/126 [00:10<00:00, 12.11it/s]
# TP: 1717 FN 164 FP 99 TN 2036
# 100% 126/126 [00:10<00:00, 11.66it/s]
# TP: 1708 FN 173 FP 100 TN 2035
# 100% 126/126 [00:10<00:00, 11.62it/s]
# TP: 1714 FN 167 FP 101 TN 2034
# 100% 126/126 [00:11<00:00, 11.40it/s]
# TP: 1707 FN 174 FP 101 TN 2034
# 100% 126/126 [00:10<00:00, 12.17it/s]
# TP: 1717 FN 164 FP 96 TN 2039

# %% [markdown]
# # **Injection Attacks**

# %%
# vanilla
# !python test_classification_inject_attack.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16 --npoints_inj 4 --clutter_size_inj 2 --num_runs 10
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=10, num_point=16, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=0, num_runs=10, is_PointGuard=False)
# Load dataset ...
# The size of test data is 4016
# 10  runs in total
# 100% 63/63 [00:10<00:00,  5.73it/s]
# 100% 63/63 [00:10<00:00,  6.20it/s]
# 100% 63/63 [00:10<00:00,  6.11it/s]
# 100% 63/63 [00:10<00:00,  5.76it/s]
# 100% 63/63 [00:10<00:00,  5.78it/s]
# 100% 63/63 [00:09<00:00,  6.30it/s]
# 100% 63/63 [00:09<00:00,  6.32it/s]
# 100% 63/63 [00:10<00:00,  6.07it/s]
# 100% 63/63 [00:10<00:00,  6.19it/s]
# 100% 63/63 [00:10<00:00,  6.14it/s]
# Data saved to log/classification/pointnet_cls_mymodelnet/epoch_10_npoint_16_bsize_64//inj_attack_comparison_npointsinj_4_cluttersizeinj_2.csv

# %%
# NoiseTrain
# !python test_classification_inject_attack.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16 --npoints_inj 4 --clutter_size_inj 2 --num_runs 10 --dropout --shift
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=True, shift=True, epoch=10, num_point=16, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=0, num_runs=10, is_PointGuard=False)
# Load dataset ...
# The size of test data is 4016
# 10  runs in total
# 100% 63/63 [00:10<00:00,  5.82it/s]
# 100% 63/63 [00:09<00:00,  6.48it/s]
# 100% 63/63 [00:11<00:00,  5.71it/s]
# 100% 63/63 [00:10<00:00,  5.79it/s]
# 100% 63/63 [00:10<00:00,  6.16it/s]
# 100% 63/63 [00:10<00:00,  5.85it/s]
# 100% 63/63 [00:10<00:00,  5.82it/s]
# 100% 63/63 [00:10<00:00,  5.95it/s]
# 100% 63/63 [00:09<00:00,  6.59it/s]
# 100% 63/63 [00:10<00:00,  5.92it/s]
# Data saved to log/classification/pointnet_cls_mymodelnet/epoch_10_npoint_16_bsize_64_dropout_shift//inj_attack_comparison_npointsinj_4_cluttersizeinj_2.csv

# %%
# AdvTrain
# !python test_classification_inject_attack.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 5 --num_point 16 --npoints_inj 4 --clutter_size_inj 2 --num_runs 10 --AdvTrain
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=5, num_point=16, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=0, num_runs=10, is_PointGuard=False, AdvTrain=True)
# Load dataset ...
# The size of test data is 4016
# 10  runs in total
# 100% 63/63 [00:10<00:00,  6.14it/s]
# 100% 63/63 [00:10<00:00,  5.90it/s]
# 100% 63/63 [00:11<00:00,  5.64it/s]
# 100% 63/63 [00:10<00:00,  5.80it/s]
# 100% 63/63 [00:10<00:00,  6.25it/s]
# 100% 63/63 [00:10<00:00,  6.04it/s]
# 100% 63/63 [00:11<00:00,  5.61it/s]
# 100% 63/63 [00:11<00:00,  5.27it/s]
# 100% 63/63 [00:11<00:00,  5.64it/s]
# 100% 63/63 [00:10<00:00,  5.82it/s]
# Data saved to log/classification/pointnet_cls_mymodelnet/AdvTrain_epoch_5_npoint_16_bsize_64//inj_attack_comparison_npointsinj_4_cluttersizeinj_2.csv

# %%
# PointGuard
# !python test_classification_inject_attack.py --log_dir pointnet_cls_mymodelnet_defense --num_category 2 --num_channel 4 --batch_size 32 --epoch 10 --num_point 16 --npoints_inj 4 --clutter_size_inj 2 --num_runs 10 --is_PointGuard
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=32, num_category=2, log_dir='pointnet_cls_mymodelnet_defense', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=10, num_point=16, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=0, num_runs=10, is_PointGuard=True)
# Load dataset ...
# The size of test data is 4016
# model: pointnet_cls_pointguard
# 10  runs in total
# 100% 126/126 [00:11<00:00, 11.44it/s]
# 100% 126/126 [00:11<00:00, 10.90it/s]
# 100% 126/126 [00:11<00:00, 10.86it/s]
# 100% 126/126 [00:11<00:00, 10.80it/s]
# 100% 126/126 [00:10<00:00, 11.72it/s]
# 100% 126/126 [00:11<00:00, 11.16it/s]
# 100% 126/126 [00:11<00:00, 10.91it/s]
# 100% 126/126 [00:11<00:00, 10.93it/s]
# 100% 126/126 [00:11<00:00, 11.01it/s]
# 100% 126/126 [00:10<00:00, 11.68it/s]
# Data saved to log/classification/pointnet_cls_mymodelnet_defense/epoch_10_npoint_16_bsize_32//inj_attack_comparison_npointsinj_4_cluttersizeinj_2.csv

# %% [markdown]
# # Architecture

# %% [markdown]
# ## old: 5-channel PointNet (Train using mixed samples)

# %%
# !python train_classification_5channel_per_inj.py --model pointnet_cls --log_dir pointnet_cls_mymodelnet_defense --num_category 2 --num_channel 4 --batch_size 32 --epoch 10 --num_point 16 --per_prob 0.4 --inject_prob 0.4
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=32, model='pointnet_cls', num_category=2, epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointnet_cls_mymodelnet_defense', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False, per_prob=0.4, inject_prob=0.4, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/10):
# 100% 292/292 [00:24<00:00, 11.82it/s]
# Train Instance Accuracy for mixed data: 0.890090
# 100% 126/126 [00:09<00:00, 13.37it/s]
# Test Instance Accuracy: 0.906746, Class Accuracy: 0.904319
# Best Instance Accuracy: 0.906746, Class Accuracy: 0.904319
# Saving at log/classification/pointnet_cls_mymodelnet_defense/epoch_10_npoint_16_bsize_32/checkpoints/best_model.pth
# Epoch 2 (2/10):
# 100% 292/292 [00:26<00:00, 11.13it/s]
# Train Instance Accuracy for mixed data: 0.922731
# ...

# %% [markdown]
# ## New: soft-mask (Train using mixed samples)

# %%
# !python train_classification_5channel_per_inj.py --model pointnet_cls_pointguard --log_dir pointnet_cls_mymodelnet_defense --num_category 2 --num_channel 4 --batch_size 32 --epoch 10 --num_point 16 --per_prob 0.4 --inject_prob 0.4
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=32, model='pointnet_cls_pointguard', num_category=2, epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointnet_cls_mymodelnet_defense', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False, per_prob=0.4, inject_prob=0.4, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# model: pointnet_cls_pointguard
# Epoch 1 (1/10):
# 100% 292/292 [00:40<00:00,  7.26it/s]
# Train Instance Accuracy for mixed data: 0.876605
# 100% 126/126 [02:08<00:00,  1.02s/it]
# Test Instance Accuracy: 0.880952, Class Accuracy: 0.880663
# Best Instance Accuracy: 0.880952, Class Accuracy: 0.880663
# Saving at log/classification/pointnet_cls_mymodelnet_defense/epoch_10_npoint_16_bsize_32/checkpoints/best_model.pth
# Epoch 2 (2/10):
# 100% 292/292 [00:26<00:00, 11.09it/s]
# ...

# %% [markdown]
# # **Attack-Agnostic Test**

# %%
# ----------------------------
# Model configs
# ----------------------------
models = {
    "Vanilla": [
        "--log_dir", "pointnet_cls_mymodelnet",
        "--num_category","2",
        "--num_channel","4",
        "--batch_size","64",
        "--epoch","10",
        "--num_point","16"
    ],

    "NoiseTrain": [
        "--log_dir", "pointnet_cls_mymodelnet",
        "--num_category","2",
        "--num_channel","4",
        "--batch_size","64",
        "--epoch","10",
        "--num_point","16",
        "--dropout",
        "--shift"
    ],

    "AdvTrain": [
        "--log_dir","pointnet_cls_mymodelnet",
        "--num_category","2",
        "--num_channel","4",
        "--batch_size","64",
        "--epoch","5",
        "--num_point","16",
        "--AdvTrain"
    ],

    "PointGuard": [
        "--log_dir","pointnet_cls_mymodelnet_defense",
        "--num_category","2",
        "--num_channel","4",
        "--batch_size","32",
        "--epoch","10",
        "--num_point","16",
        "--is_PointGuard"
    ]
}


# ----------------------------
# Attack scenarios
# ----------------------------
scenarios = {

    "no_attack": [
        "--per_prob","0",
        "--inject_prob","0"
    ],

    "mix_attack":[
        "--per_prob","0.4",
        "--inject_prob","0.4"
    ],

    "doppler_attack":[
        "--per_prob","0.9",
        "--inject_prob","0",
        "--channels_per","3",
        "--eps_per","3"
    ],
    "removal_attack":[
        "--removal_prob","0.6"
    ]
}

# %%
# models
# Vanilla: --log_dir pointnet_cls_mymodelnet  --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# NoiseTrain: --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 10 --num_point 16 --dropout --shift
# AdvTrain: --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --batch_size 64 --epoch 5 --num_point 16 --AdvTrain
# PointGuard: --log_dir pointnet_cls_mymodelnet_defense --num_category 2 --num_channel 4 --batch_size 32 --epoch 10 --num_point 16 --is_PointGuard
# scenario
# no_attack: --per_prob 0 --inject_prob 0
# mix_attack:  --per_prob 0.5 --inject_prob 0.5
# doppler_attack: --per_prob 0.9 --inject_prob 0 --channels_per 3 --eps_per 3
# removal_attack: --removal_prob 0.9
# extreme_perturbation: --per_prob 0.9 --inject_prob 0 --eps_per 5
# scale_attack: --scale_prob 0.9

# %%
# accuracy
# !python test_classification_attack_single_run.py --model_json PointGuard --att_scenario_json doppler_attack --per_prob 0.9 --inject_prob 0 --channels_per 3 --eps_per 3 --log_dir pointnet_cls_mymodelnet_defense --num_category 2 --num_channel 4 --batch_size 32 --epoch 10 --num_point 16 --is_PointGuard
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=32, num_category=2, log_dir='pointnet_cls_mymodelnet_defense', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=10, num_point=16, per_prob=0.9, inject_prob=0.0, removal_prob=0, scale_prob=0, npoints_inj=3, clutter_size_inj=1, channels_per=[3], eps_per=3.0, num_runs=5, is_PointGuard=True, AdvTrain=False, model_json='PointGuard', att_scenario_json='doppler_attack')
# Load dataset ...
# The size of test data is 4016
# model: pointnet_cls_pointguard
# 5  runs in total
# 100% 126/126 [00:12<00:00, 10.40it/s]
# 100% 126/126 [00:11<00:00, 10.67it/s]
# 100% 126/126 [00:13<00:00,  9.64it/s]
# 100% 126/126 [00:12<00:00, 10.01it/s]
# 100% 126/126 [00:13<00:00,  9.69it/s]
