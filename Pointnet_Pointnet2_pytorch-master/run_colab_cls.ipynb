# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# ## Try PointNet for classification on MyModelNet2 (car & clutter)

# %%
# !python train_classification.py --model pointnet_cls --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --epoch 5 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, model='pointnet_cls', num_category=2, epoch=5, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointnet_cls_mymodelnet', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False, dropout=False, shift=False)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/5):
# 100% 390/390 [13:32<00:00,  2.08s/it]
# Train Instance Accuracy: 0.920406
# 100% 168/168 [05:47<00:00,  2.07s/it]
# Test Instance Accuracy: 0.959573, Class Accuracy: 0.960647
# Best Instance Accuracy: 0.959573, Class Accuracy: 0.960647
# Saving at log/classification/pointnet_cls_mymodelnet/epoch_5_npoint_16/checkpoints/best_model.pth
# Epoch 2 (2/5):
# 100% 390/390 [00:15<00:00, 25.49it/s]
# Train Instance Accuracy: 0.938248
# 100% 168/168 [00:04<00:00, 34.85it/s]
# Test Instance Accuracy: 0.949157, Class Accuracy: 0.950925
# ...

# %%
# !python test_classification.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --num_point 8 --epoch 5 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=5, num_point=16)
# Load dataset ...
# The size of test data is 4016
# 100% 168/168 [00:05<00:00, 32.37it/s]
# Test Instance Accuracy: 0.960813, Class Accuracy: 0.961708

# %% [markdown]
# ## Attack

# %%
# !python test_classification_attack.py --log_dir pointnet_cls_mymodelnet --num_category 2 --num_channel 4 --num_point 8 --epoch 5 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, num_category=2, log_dir='pointnet_cls_mymodelnet', num_channel=4, use_uniform_sample=False, num_votes=3, dropout=False, shift=False, epoch=5, num_point=16)
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:05<00:00, 12.46it/s]
# Perturbation channels: [0, 1, 2], Perturbation epsilon: 0.000000
# Test Instance Accuracy: 0.960648, Class Accuracy: 0.960933
# 100% 63/63 [00:05<00:00, 12.40it/s]
# Perturbation channels: [3], Perturbation epsilon: 0.000000
# Test Instance Accuracy: 0.960648, Class Accuracy: 0.960933
# 100% 63/63 [00:05<00:00, 12.35it/s]
# Perturbation channels: [0, 1, 2, 3], Perturbation epsilon: 0.000000
# Test Instance Accuracy: 0.960648, Class Accuracy: 0.960933
# 100% 63/63 [00:04<00:00, 12.94it/s]
# Perturbation channels: [0, 1, 2], Perturbation epsilon: 0.100000
# Test Instance Accuracy: 0.957920, Class Accuracy: 0.958595
# 100% 63/63 [00:04<00:00, 12.71it/s]
# ...
