# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# ## Train PointGuard (using cls samples and shift adversarial attacks)

# %%
# !python train_pointguard.py --model pointnet_pointguard --log_dir pointguard_classification_shift_attack --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_pointguard', epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointguard_classification_shift_attack', decay_rate=0.0001, num_channel=4)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/10):
# 100% 146/146 [00:25<00:00,  5.76it/s]
# Train MSE loss: 0.108577
# 100% 63/63 [00:10<00:00,  5.85it/s]
# Test MSE loss: 0.106517
# Best test MSE loss: 0.106517
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 2 (2/10):
# 100% 146/146 [00:24<00:00,  6.04it/s]
# Train MSE loss: 0.076608
# 100% 63/63 [00:10<00:00,  6.09it/s]
# Test MSE loss: 0.086064
# Best test MSE loss: 0.086064
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 3 (3/10):
# 100% 146/146 [00:26<00:00,  5.54it/s]
# Train MSE loss: 0.065181
# 100% 63/63 [00:10<00:00,  5.99it/s]
# Test MSE loss: 0.082542
# Best test MSE loss: 0.082542
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 4 (4/10):
# 100% 146/146 [00:24<00:00,  5.89it/s]
# Train MSE loss: 0.058099
# 100% 63/63 [00:11<00:00,  5.71it/s]
# Test MSE loss: 0.087749
# Best test MSE loss: 0.082542
# Epoch 5 (5/10):
# 100% 146/146 [00:25<00:00,  5.69it/s]
# Train MSE loss: 0.050929
# 100% 63/63 [00:09<00:00,  6.77it/s]
# Test MSE loss: 0.071666
# Best test MSE loss: 0.071666
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 6 (6/10):
# 100% 146/146 [00:25<00:00,  5.62it/s]
# Train MSE loss: 0.046210
# 100% 63/63 [00:10<00:00,  6.02it/s]
# Test MSE loss: 0.077559
# Best test MSE loss: 0.071666
# Epoch 7 (7/10):
# 100% 146/146 [00:24<00:00,  5.94it/s]
# Train MSE loss: 0.045926
# 100% 63/63 [00:09<00:00,  6.48it/s]
# Test MSE loss: 0.084558
# Best test MSE loss: 0.071666
# Epoch 8 (8/10):
# 100% 146/146 [00:24<00:00,  5.92it/s]
# Train MSE loss: 0.041679
# 100% 63/63 [00:09<00:00,  6.86it/s]
# Test MSE loss: 0.069722
# Best test MSE loss: 0.069722
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 9 (9/10):
# 100% 146/146 [00:25<00:00,  5.83it/s]
# Train MSE loss: 0.040563
# 100% 63/63 [00:10<00:00,  5.99it/s]
# Test MSE loss: 0.067250
# Best test MSE loss: 0.067250
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 10 (10/10):
# 100% 146/146 [00:24<00:00,  5.84it/s]
# Train MSE loss: 0.038550
# 100% 63/63 [00:09<00:00,  6.50it/s]
# Test MSE loss: 0.059916
# Best test MSE loss: 0.059916
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
