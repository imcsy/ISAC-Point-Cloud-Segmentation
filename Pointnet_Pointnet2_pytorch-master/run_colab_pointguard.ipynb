# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# ## Train PointGuard (using mixing loader, clean + perturbed + injection)

# %%
# !python train_pointguard.py --model pointnet_pointguard --log_dir pointguard_classification_shift_attack --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_pointguard', epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointguard_classification_shift_attack', decay_rate=0.0001, num_channel=4, per_prob=0.4, inject_prob=0.4, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1, num_category=2)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/10):
# 100% 146/146 [00:25<00:00,  5.63it/s]
# Train MSE loss: 0.176727
# 100% 63/63 [00:10<00:00,  5.77it/s]
# Test MSE loss: 0.162728
# Best test MSE loss: 0.162728
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 2 (2/10):
# 100% 146/146 [00:26<00:00,  5.41it/s]
# Train MSE loss: 0.145654
# 100% 63/63 [00:11<00:00,  5.53it/s]
# Test MSE loss: 0.135619
# Best test MSE loss: 0.135619
# ...

# %%
# !python test_pointguard.py --log_dir pointguard_classification_shift_attack --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, log_dir='pointguard_classification_shift_attack', num_channel=4, epoch=10, num_point=16)
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:12<00:00,  5.04it/s]
# Test MSE loss: 0.068731

# %% [markdown]
# ## Test PointGuard / SOR for perturbation / injection attack

# %%
# !python pointguard_test_threshold.py --log_dir pointguard_classification_mix
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, log_dir='pointguard_classification_mix', num_channel=4, epoch=10, num_point=16, per_prob=1, inject_prob=0, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1, num_category=2)
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:10<00:00,  6.06it/s]
