# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# ## Train PointGuard (using mixing loader, clean + perturbed + injection)

# %%
# !python train_pointguard.py --model pointnet_pointguard --log_dir pointguard_classification_mix
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_pointguard', epoch=20, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointguard_classification_mix', decay_rate=0.0001, num_channel=4, per_prob=0.4, inject_prob=0.4, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=0.5, num_category=2)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/20):
# 100% 146/146 [06:34<00:00,  2.70s/it]
# Train MSE loss: 0.151879
# 100% 63/63 [03:59<00:00,  3.81s/it]
# Test MSE loss: 0.157752
# Best test MSE loss: 0.157752
# Saving at log/pointguard/pointguard_classification_mix/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 2 (2/20):
# 100% 146/146 [00:24<00:00,  5.93it/s]
# Train MSE loss: 0.130531
# 100% 63/63 [00:10<00:00,  5.83it/s]
# Test MSE loss: 0.117594
# Best test MSE loss: 0.117594
# Saving at log/pointguard/pointguard_classification_mix/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 3 (3/20):
# 100% 146/146 [00:26<00:00,  5.45it/s]
# Train MSE loss: 0.116196
# 100% 63/63 [00:09<00:00,  6.31it/s]
# Test MSE loss: 0.143250
# Best test MSE loss: 0.117594
# Epoch 4 (4/20):
# 100% 146/146 [00:25<00:00,  5.72it/s]
# Train MSE loss: 0.110031
# 100% 63/63 [00:10<00:00,  5.74it/s]
# Test MSE loss: 0.211703
# Best test MSE loss: 0.117594
# Epoch 5 (5/20):
# 100% 146/146 [00:24<00:00,  5.95it/s]
# Train MSE loss: 0.104351
# 100% 63/63 [00:10<00:00,  6.10it/s]
# Test MSE loss: 0.091294
# Best test MSE loss: 0.091294
# Saving at log/pointguard/pointguard_classification_mix/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 6 (6/20):
# 100% 146/146 [00:26<00:00,  5.46it/s]
# Train MSE loss: 0.095345
# 100% 63/63 [00:10<00:00,  6.29it/s]
# Test MSE loss: 0.096144
# Best test MSE loss: 0.091294
# Epoch 7 (7/20):
# 100% 146/146 [00:24<00:00,  6.02it/s]
# Train MSE loss: 0.085153
# 100% 63/63 [00:11<00:00,  5.70it/s]
# Test MSE loss: 0.104779
# Best test MSE loss: 0.091294
# Epoch 8 (8/20):
# 100% 146/146 [00:24<00:00,  5.97it/s]
# Train MSE loss: 0.074241
# 100% 63/63 [00:10<00:00,  6.17it/s]
# Test MSE loss: 0.322439
# Best test MSE loss: 0.091294
# Epoch 9 (9/20):
# 100% 146/146 [00:25<00:00,  5.78it/s]
# Train MSE loss: 0.074700
# 100% 63/63 [00:09<00:00,  6.62it/s]
# Test MSE loss: 0.099465
# Best test MSE loss: 0.091294
# Epoch 10 (10/20):
# 100% 146/146 [00:24<00:00,  6.00it/s]
# Train MSE loss: 0.069969
# 100% 63/63 [00:10<00:00,  6.04it/s]
# Test MSE loss: 0.151404
# Best test MSE loss: 0.091294
# Epoch 11 (11/20):
# 100% 146/146 [00:23<00:00,  6.18it/s]
# Train MSE loss: 0.063661
# 100% 63/63 [00:10<00:00,  6.05it/s]
# Test MSE loss: 0.128813
# Best test MSE loss: 0.091294
# Epoch 12 (12/20):
# 100% 146/146 [00:24<00:00,  5.95it/s]
# Train MSE loss: 0.065659
# 100% 63/63 [00:09<00:00,  6.65it/s]
# Test MSE loss: 0.125561
# Best test MSE loss: 0.091294
# Epoch 13 (13/20):
# 100% 146/146 [00:24<00:00,  5.95it/s]
# Train MSE loss: 0.066820
# 100% 63/63 [00:10<00:00,  6.26it/s]
# Test MSE loss: 0.142840
# Best test MSE loss: 0.091294
# Epoch 14 (14/20):
# 100% 146/146 [00:23<00:00,  6.21it/s]
# Train MSE loss: 0.059873
# 100% 63/63 [00:10<00:00,  5.99it/s]
# Test MSE loss: 0.087559
# Best test MSE loss: 0.087559
# Saving at log/pointguard/pointguard_classification_mix/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 15 (15/20):
# 100% 146/146 [00:25<00:00,  5.73it/s]
# Train MSE loss: 0.057559
# 100% 63/63 [00:09<00:00,  6.62it/s]
# Test MSE loss: 0.160828
# Best test MSE loss: 0.087559
# Epoch 16 (16/20):
# 100% 146/146 [00:25<00:00,  5.83it/s]
# Train MSE loss: 0.055543
# 100% 63/63 [00:09<00:00,  6.63it/s]
# Test MSE loss: 0.177162
# Best test MSE loss: 0.087559
# Epoch 17 (17/20):
# 100% 146/146 [00:24<00:00,  6.07it/s]
# Train MSE loss: 0.051924
# 100% 63/63 [00:10<00:00,  5.96it/s]
# Test MSE loss: 0.140798
# Best test MSE loss: 0.087559
# Epoch 18 (18/20):
# 100% 146/146 [00:23<00:00,  6.20it/s]
# Train MSE loss: 0.051999
# 100% 63/63 [00:10<00:00,  6.21it/s]
# Test MSE loss: 0.075759
# Best test MSE loss: 0.075759
# Saving at log/pointguard/pointguard_classification_mix/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 19 (19/20):
# 100% 146/146 [00:26<00:00,  5.44it/s]
# Train MSE loss: 0.048389
# 100% 63/63 [00:09<00:00,  6.69it/s]
# Test MSE loss: 0.075922
# Best test MSE loss: 0.075759
# Epoch 20 (20/20):
# 100% 146/146 [00:24<00:00,  6.01it/s]
# Train MSE loss: 0.046816
# 100% 63/63 [00:10<00:00,  6.03it/s]
# Test MSE loss: 0.047301
# Best test MSE loss: 0.047301
# Saving at log/pointguard/pointguard_classification_mix/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth

# %%
# !python train_pointguard.py --model pointnet_pointguard_small --log_dir pointguard_classification_mix_small
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_pointguard_small', epoch=20, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointguard_classification_mix_small', decay_rate=0.0001, num_channel=4, per_prob=0.4, inject_prob=0.4, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=0.5, num_category=2)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/20):
# 100% 146/146 [03:13<00:00,  1.32s/it]
# Train MSE loss: 0.142594
# 100% 63/63 [02:37<00:00,  2.50s/it]
# Test MSE loss: 0.124060
# Best test MSE loss: 0.124060
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 2 (2/20):
# 100% 146/146 [00:21<00:00,  6.75it/s]
# Train MSE loss: 0.118661
# 100% 63/63 [00:09<00:00,  6.32it/s]
# Test MSE loss: 0.110758
# Best test MSE loss: 0.110758
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 3 (3/20):
# 100% 146/146 [00:21<00:00,  6.75it/s]
# Train MSE loss: 0.103721
# 100% 63/63 [00:08<00:00,  7.12it/s]
# Test MSE loss: 0.093221
# Best test MSE loss: 0.093221
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 4 (4/20):
# 100% 146/146 [00:22<00:00,  6.52it/s]
# Train MSE loss: 0.094218
# 100% 63/63 [00:08<00:00,  7.30it/s]
# Test MSE loss: 0.093892
# Best test MSE loss: 0.093221
# Epoch 5 (5/20):
# 100% 146/146 [00:22<00:00,  6.51it/s]
# Train MSE loss: 0.088652
# 100% 63/63 [00:08<00:00,  7.53it/s]
# Test MSE loss: 0.088780
# Best test MSE loss: 0.088780
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 6 (6/20):
# 100% 146/146 [00:22<00:00,  6.50it/s]
# Train MSE loss: 0.086604
# 100% 63/63 [00:08<00:00,  7.15it/s]
# Test MSE loss: 0.086379
# Best test MSE loss: 0.086379
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 7 (7/20):
# 100% 146/146 [00:21<00:00,  6.72it/s]
# Train MSE loss: 0.084263
# 100% 63/63 [00:09<00:00,  6.85it/s]
# Test MSE loss: 0.080950
# Best test MSE loss: 0.080950
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 8 (8/20):
# 100% 146/146 [00:21<00:00,  6.78it/s]
# Train MSE loss: 0.079908
# 100% 63/63 [00:09<00:00,  6.71it/s]
# Test MSE loss: 0.079468
# Best test MSE loss: 0.079468
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 9 (9/20):
# 100% 146/146 [00:20<00:00,  6.98it/s]
# Train MSE loss: 0.079175
# 100% 63/63 [00:09<00:00,  6.54it/s]
# Test MSE loss: 0.080469
# Best test MSE loss: 0.079468
# Epoch 10 (10/20):
# 100% 146/146 [00:21<00:00,  6.91it/s]
# Train MSE loss: 0.077211
# 100% 63/63 [00:09<00:00,  6.75it/s]
# Test MSE loss: 0.078788
# Best test MSE loss: 0.078788
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 11 (11/20):
# 100% 146/146 [00:20<00:00,  6.99it/s]
# Train MSE loss: 0.075627
# 100% 63/63 [00:09<00:00,  6.69it/s]
# Test MSE loss: 0.076542
# Best test MSE loss: 0.076542
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 12 (12/20):
# 100% 146/146 [00:21<00:00,  6.91it/s]
# Train MSE loss: 0.073535
# 100% 63/63 [00:09<00:00,  6.84it/s]
# Test MSE loss: 0.073289
# Best test MSE loss: 0.073289
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 13 (13/20):
# 100% 146/146 [00:21<00:00,  6.70it/s]
# Train MSE loss: 0.071746
# 100% 63/63 [00:08<00:00,  7.32it/s]
# Test MSE loss: 0.073348
# Best test MSE loss: 0.073289
# Epoch 14 (14/20):
# 100% 146/146 [00:22<00:00,  6.61it/s]
# Train MSE loss: 0.071778
# 100% 63/63 [00:08<00:00,  7.75it/s]
# Test MSE loss: 0.068913
# Best test MSE loss: 0.068913
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 15 (15/20):
# 100% 146/146 [00:22<00:00,  6.60it/s]
# Train MSE loss: 0.068596
# 100% 63/63 [00:08<00:00,  7.60it/s]
# Test MSE loss: 0.069899
# Best test MSE loss: 0.068913
# Epoch 16 (16/20):
# 100% 146/146 [00:22<00:00,  6.54it/s]
# Train MSE loss: 0.066388
# 100% 63/63 [00:08<00:00,  7.18it/s]
# Test MSE loss: 0.068093
# Best test MSE loss: 0.068093
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 17 (17/20):
# 100% 146/146 [00:21<00:00,  6.83it/s]
# Train MSE loss: 0.064074
# 100% 63/63 [00:09<00:00,  6.76it/s]
# Test MSE loss: 0.070778
# Best test MSE loss: 0.068093
# Epoch 18 (18/20):
# 100% 146/146 [00:20<00:00,  6.97it/s]
# Train MSE loss: 0.063899
# 100% 63/63 [00:09<00:00,  6.42it/s]
# Test MSE loss: 0.063971
# Best test MSE loss: 0.063971
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 19 (19/20):
# 100% 146/146 [00:20<00:00,  6.98it/s]
# Train MSE loss: 0.061632
# 100% 63/63 [00:09<00:00,  6.45it/s]
# Test MSE loss: 0.065329
# Best test MSE loss: 0.063971
# Epoch 20 (20/20):
# 100% 146/146 [00:20<00:00,  6.99it/s]
# Train MSE loss: 0.056921
# 100% 63/63 [00:09<00:00,  6.41it/s]
# Test MSE loss: 0.056775
# Best test MSE loss: 0.056775
# Saving at log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/checkpoints/best_model.pth

# %% [markdown]
# ## Test PointGuard / SOR for perturbation / injection attack

# %%
# !python pointguard_baseline_test_ROC.py --log_dir pointguard_classification_mix --per_prob 0.4 --inject_prob 0.4 --baseline spr
# pointguard, sor, spr, discriminator
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, log_dir='pointguard_classification_mix', num_channel=4, epoch=10, num_point=16, per_prob=0.4, inject_prob=0.4, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1, num_category=2, baseline='spr')
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:11<00:00,  5.30it/s]

# %% [markdown]
# ## Discriminator (binary cls)

# %%
# !python train_discriminator.py --log_dir pointnet_discriminator_mymodelnet
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_cls', num_category=2, epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointnet_discriminator_mymodelnet', decay_rate=0.0001, num_channel=4, process_data=False, use_uniform_sample=False, per_prob=0.4, inject_prob=0.4, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/10):
# 100% 146/146 [00:23<00:00,  6.25it/s]
# Train Instance Accuracy for mixed data: 0.804688
# 100% 63/63 [02:49<00:00,  2.68s/it]
# Saving at log/classification/pointnet_discriminator_mymodelnet/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Test Instance Accuracy: 0.902447
# Best Instance Accuracy: 0.902447
# Epoch 2 (2/10):
# 100% 146/146 [00:21<00:00,  6.78it/s]
# Train Instance Accuracy for mixed data: 0.886451
# 100% 63/63 [00:09<00:00,  6.32it/s]
# Saving at log/classification/pointnet_discriminator_mymodelnet/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Test Instance Accuracy: 0.907738
# Best Instance Accuracy: 0.907738
# Epoch 3 (3/10):
# 100% 146/146 [00:23<00:00,  6.16it/s]
# Train Instance Accuracy for mixed data: 0.915026
# 100% 63/63 [00:09<00:00,  6.92it/s]
# Saving at log/classification/pointnet_discriminator_mymodelnet/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Test Instance Accuracy: 0.923942
# Best Instance Accuracy: 0.923942
# Epoch 4 (4/10):
# 100% 146/146 [00:24<00:00,  5.99it/s]
# Train Instance Accuracy for mixed data: 0.921875
# 100% 63/63 [00:08<00:00,  7.15it/s]
# Saving at log/classification/pointnet_discriminator_mymodelnet/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Test Instance Accuracy: 0.948330
# Best Instance Accuracy: 0.948330
# Epoch 5 (5/10):
# 100% 146/146 [00:23<00:00,  6.25it/s]
# Train Instance Accuracy for mixed data: 0.932577
# 100% 63/63 [00:09<00:00,  6.48it/s]
# Test Instance Accuracy: 0.922784
# Best Instance Accuracy: 0.948330
# Epoch 6 (6/10):
# 100% 146/146 [00:21<00:00,  6.79it/s]
# Train Instance Accuracy for mixed data: 0.933647
# 100% 63/63 [00:09<00:00,  6.51it/s]
# Test Instance Accuracy: 0.939815
# Best Instance Accuracy: 0.948330
# Epoch 7 (7/10):
# 100% 146/146 [00:21<00:00,  6.74it/s]
# Train Instance Accuracy for mixed data: 0.931079
# 100% 63/63 [00:09<00:00,  6.55it/s]
# Test Instance Accuracy: 0.947090
# Best Instance Accuracy: 0.948330
# Epoch 8 (8/10):
# 100% 146/146 [00:22<00:00,  6.60it/s]
# Train Instance Accuracy for mixed data: 0.944991
# 100% 63/63 [00:09<00:00,  6.85it/s]
# Saving at log/classification/pointnet_discriminator_mymodelnet/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Test Instance Accuracy: 0.956019
# Best Instance Accuracy: 0.956019
# Epoch 9 (9/10):
# 100% 146/146 [00:24<00:00,  6.07it/s]
# Train Instance Accuracy for mixed data: 0.951520
# 100% 63/63 [00:08<00:00,  7.53it/s]
# Test Instance Accuracy: 0.955522
# Best Instance Accuracy: 0.956019
# Epoch 10 (10/10):
# 100% 146/146 [00:22<00:00,  6.44it/s]
# Train Instance Accuracy for mixed data: 0.956336
# 100% 63/63 [00:09<00:00,  6.96it/s]
# Test Instance Accuracy: 0.952381
# Best Instance Accuracy: 0.956019

# %% [markdown]
# ## Sensitivity

# %%
# !python pointguard_sensitivity.py --log_dir pointguard_classification_mix --per_prob 0 --inject_prob 0.8 --baseline pointguard
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, log_dir='pointguard_classification_mix', num_channel=4, epoch=10, num_point=16, per_prob=0.0, inject_prob=0.8, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1, num_category=2, baseline='pointguard')
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:10<00:00,  6.15it/s]
# The size of test data is 4016
# 100% 63/63 [00:09<00:00,  6.96it/s]
# The size of test data is 4016
# 100% 63/63 [00:09<00:00,  6.53it/s]
# The size of test data is 4016
# 100% 63/63 [00:10<00:00,  6.26it/s]
# The size of test data is 4016
# 100% 63/63 [00:09<00:00,  6.90it/s]
# Saved results cleanly using Pandas to /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/log/pointguard/pointguard_classification_mix/epoch_10_npoint_16_bsize_64/numerical result/inj_sensitivity.json
# The size of test data is 4016
# 100% 63/63 [00:09<00:00,  6.38it/s]
# The size of test data is 4016
# 100% 63/63 [00:10<00:00,  6.09it/s]
# The size of test data is 4016
# 100% 63/63 [00:09<00:00,  6.39it/s]
# The size of test data is 4016
# 100% 63/63 [00:09<00:00,  6.52it/s]
# The size of test data is 4016
# 100% 63/63 [00:10<00:00,  5.98it/s]
# Saved results cleanly using Pandas to /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/log/pointguard/pointguard_classification_mix/epoch_10_npoint_16_bsize_64/numerical result/inj_sensitivity.json
# The size of test data is 4016
# 100% 63/63 [00:11<00:00,  5.32it/s]
# The size of test data is 4016
# 100% 63/63 [00:11<00:00,  5.69it/s]
# The size of test data is 4016
# 100% 63/63 [00:10<00:00,  5.80it/s]
# The size of test data is 4016
# 100% 63/63 [00:11<00:00,  5.45it/s]
# The size of test data is 4016
# 100% 63/63 [00:11<00:00,  5.49it/s]
# Saved results cleanly using Pandas to /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/log/pointguard/pointguard_classification_mix/epoch_10_npoint_16_bsize_64/numerical result/inj_sensitivity.json
# The size of test data is 4016
# 100% 63/63 [00:24<00:00,  2.54it/s]
# The size of test data is 4016
# 100% 63/63 [00:25<00:00,  2.44it/s]
# The size of test data is 4016
# 100% 63/63 [00:29<00:00,  2.14it/s]
# The size of test data is 4016
# 100% 63/63 [00:24<00:00,  2.62it/s]
# The size of test data is 4016
# 100% 63/63 [00:23<00:00,  2.67it/s]
# Saved results cleanly using Pandas to /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/log/pointguard/pointguard_classification_mix/epoch_10_npoint_16_bsize_64/numerical result/inj_sensitivity.json
# The size of test data is 4016
# 100% 63/63 [00:43<00:00,  1.44it/s]
# The size of test data is 4016
# 100% 63/63 [00:55<00:00,  1.14it/s]
# The size of test data is 4016
# 100% 63/63 [01:00<00:00,  1.05it/s]
# The size of test data is 4016
# 100% 63/63 [00:52<00:00,  1.19it/s]
# The size of test data is 4016
# 100% 63/63 [01:03<00:00,  1.00s/it]
# Saved results cleanly using Pandas to /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/log/pointguard/pointguard_classification_mix/epoch_10_npoint_16_bsize_64/numerical result/inj_sensitivity.json

# %% [markdown]
# ## Ablation Study: Use PointNet for binary cls directly (segmentation model)

# %%
# train pointnet for segmentation task
# !python train_pointnet_binary_seg.py --log_dir pointnet_ablation_pointguard --epoch 5
# Out:
# PARAMETER ...
# Namespace(model='pointnet_sem_seg', batch_size=64, epoch=5, learning_rate=0.001, gpu='0', optimizer='Adam', log_dir='pointnet_ablation_pointguard', decay_rate=0.0001, num_point=16, step_size=10, lr_decay=0.7, samples_per_frame=4, dropout=False, shift=False, per_prob=0.4, inject_prob=0.4, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1, num_category=2, num_channel=4)
# The size of train data is 9368
# The size of test data is 4016
# The number of training data is: 9368
# The number of test data is: 4016
# No existing model, starting training from scratch...
# **** Epoch 1 (1/5) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 146/146 [00:24<00:00,  5.92it/s]
# Training mean loss: 0.648320
# Training accuracy: 0.522066
# ---- EPOCH 001 EVALUATION ----
#  43% 63/146 [00:09<00:12,  6.88it/s]
# eval point accuracy: 0.668682
# Saving at log/sem_seg/pointnet_ablation_pointguard/epoch_5_npoint_16_bsize_64/checkpoints/best_model.pth
# Saving model....
# Best Point Accuracy: 0.668682
# **** Epoch 2 (2/5) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 146/146 [00:24<00:00,  6.07it/s]
# Training mean loss: 0.564813
# Training accuracy: 0.625134
# ---- EPOCH 002 EVALUATION ----
#  43% 63/146 [00:10<00:13,  6.07it/s]
# eval point accuracy: 0.670805
# Saving at log/sem_seg/pointnet_ablation_pointguard/epoch_5_npoint_16_bsize_64/checkpoints/best_model.pth
# Saving model....
# Best Point Accuracy: 0.670805
# **** Epoch 3 (3/5) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 146/146 [00:24<00:00,  5.89it/s]
# Training mean loss: 0.510082
# Training accuracy: 0.677179
# ---- EPOCH 003 EVALUATION ----
#  43% 63/146 [00:09<00:12,  6.45it/s]
# eval point accuracy: 0.710410
# Saving at log/sem_seg/pointnet_ablation_pointguard/epoch_5_npoint_16_bsize_64/checkpoints/best_model.pth
# Saving model....
# Best Point Accuracy: 0.710410
# **** Epoch 4 (4/5) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 146/146 [00:25<00:00,  5.65it/s]
# Training mean loss: 0.461278
# Training accuracy: 0.724757
# ---- EPOCH 004 EVALUATION ----
#  43% 63/146 [00:09<00:13,  6.31it/s]
# eval point accuracy: 0.748016
# Saving at log/sem_seg/pointnet_ablation_pointguard/epoch_5_npoint_16_bsize_64/checkpoints/best_model.pth
# Saving model....
# Best Point Accuracy: 0.748016
# **** Epoch 5 (5/5) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 146/146 [00:24<00:00,  5.97it/s]
# Training mean loss: 0.452516
# Training accuracy: 0.736783
# ---- EPOCH 005 EVALUATION ----
#  43% 63/146 [00:10<00:13,  5.97it/s]
# eval point accuracy: 0.759487
# Saving at log/sem_seg/pointnet_ablation_pointguard/epoch_5_npoint_16_bsize_64/checkpoints/best_model.pth
# Saving model....
# Best Point Accuracy: 0.759487

# %%
# !python pointguard_ablation.py --log_dir pointguard_classification_mix --attack_scenario doppler --per_prob 1 --inject_prob 0 --eps_per 1.5 --channels_per 3 --baseline pointnet_seg
# pointnet_seg pointguard
# Mixed Attack
# --attack_scenario mixed --per_prob 0.4 --inject_prob 0.4
# Small Attack
# --attack_scenario small --per_prob 1 --inject_prob 0 --eps_per 0.5
# Extreme Attack
# --attack_scenario extreme --per_prob 1 --inject_prob 0 --eps_per 3
# Dopper Attack
# --attack_scenario doppler --per_prob 1 --inject_prob 0 --eps_per 1.5 --channels_per 3
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, log_dir='pointguard_classification_mix', num_channel=4, epoch=10, num_point=16, per_prob=1.0, inject_prob=0.0, npoints_inj=4, clutter_size_inj=2, channels_per=[3], eps_per=1.5, num_category=2, baseline='pointnet_seg', attack_scenario='doppler')
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:10<00:00,  5.83it/s]
# The size of test data is 4016
# 100% 63/63 [00:11<00:00,  5.67it/s]
# The size of test data is 4016
# 100% 63/63 [00:11<00:00,  5.67it/s]
# The size of test data is 4016
# 100% 63/63 [00:09<00:00,  6.38it/s]
# The size of test data is 4016
# 100% 63/63 [00:10<00:00,  5.98it/s]
# Saved results cleanly using Pandas to /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/log/pointguard/pointguard_classification_mix/epoch_10_npoint_16_bsize_64/numerical result/ablation.json

# %%
# !python pointguard_ablation_latent_feat.py --log_dir pointguard_classification_mix_small
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, log_dir='pointguard_classification_mix_small', num_channel=4, epoch=20, num_point=16, per_prob=0.8, inject_prob=0, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1, num_category=2)
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:10<00:00,  6.28it/s]
#  Successfully saved visualization data to /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/log/pointguard/pointguard_classification_mix_small/epoch_20_npoint_16_bsize_64/numerical result/ablation_data.pt!

# %% [markdown]
# ## PointGuard downstream discriminator

# %%
# !python train_pointguard_downstream_discriminator.py --log_dir pointguard_downstream_discriminator
# Out:
# PARAMETER ...
# Namespace(model='pointguard_discriminator', batch_size=64, epoch=5, learning_rate=0.001, gpu='0', optimizer='Adam', log_dir='pointguard_downstream_discriminator', decay_rate=0.0001, num_point=16, step_size=10, lr_decay=0.7, samples_per_frame=4, dropout=False, shift=False, per_prob=0.4, inject_prob=0.4, npoints_inj=4, clutter_size_inj=2, channels_per=[0, 1, 2, 3], eps_per=1, num_category=2, num_channel=5)
# The size of train data is 9368
# The size of test data is 4016
# The number of training data is: 9368
# The number of test data is: 4016
# No existing model, starting training from scratch...
# **** Epoch 1 (1/5) ****
# Learning rate:0.001000
# BN momentum updated to: 0.100000
# 100% 146/146 [00:22<00:00,  6.44it/s]
# Training mean loss: 0.372184
# Training accuracy: 0.779130
# ---- EPOCH 001 EVALUATION ----
#   7% 10/146 [00:03<00:47,  2.87it/s]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 741, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1524, in _next_data
#     idx, data = self._get_data()
#                 ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1483, in _get_data
#     success, data = self._try_get_data()
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1310, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 113, in get
#     if not self._poll(timeout):
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 440, in _poll
#     r = wait([self], timeout)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 1136, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/train_pointguard_downstream_discriminator.py", line 288, in <module>
#     main(args)
#   File "/content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master/train_pointguard_downstream_discriminator.py", line 240, in main
#     for i, (points_aug, _, _) in tqdm(enumerate(testDataLoader), total=len(trainDataLoader), smoothing=0.9):
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 737, in __next__
#     with torch.autograd.profiler.record_function(self._profile_name):
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/profiler.py", line 819, in __exit__
#     torch.ops.profiler._record_function_exit._RecordFunction(record)
#   File "/usr/local/lib/python3.12/dist-packages/torch/_ops.py", line 1032, in __call__
#     if _must_dispatch_in_python(args, kwargs):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_ops.py", line 1082, in _must_dispatch_in_python
#     return pytree.tree_any(
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_pytree.py", line 1790, in tree_any
#     return any(map(pred, flat_args))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_pytree.py", line 1476, in tree_iter
#     yield from tree_iter(child, is_leaf=is_leaf)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_pytree.py", line 1472, in tree_iter
#     child_pytrees, _ = flatten_fn(tree)
#                        ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_pytree.py", line 802, in _dict_flatten
#     return list(d.values()), list(d.keys())
#                 ^^^^^^^^^^
# KeyboardInterrupt
