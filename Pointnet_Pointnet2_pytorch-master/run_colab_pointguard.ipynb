# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# ## Train PointGuard (using cls samples and shift adversarial attacks)

# %%
# !python train_pointguard.py --model pointnet_pointguard --log_dir pointguard_classification_shift_attack --num_channel 4 --batch_size 64 --epoch 5 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_pointguard', epoch=5, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointguard_classification_shift_attack', decay_rate=0.0001, num_channel=4)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/5):
# 100% 146/146 [00:26<00:00,  5.43it/s]
# Train Instance Accuracy: 0.101503
# Epoch 1 (2/5):
# 100% 146/146 [00:25<00:00,  5.62it/s]
# Train Instance Accuracy: 0.072206
# Epoch 1 (3/5):
# 100% 146/146 [00:25<00:00,  5.68it/s]
# Train Instance Accuracy: 0.061604
# Epoch 1 (4/5):
# 100% 146/146 [00:24<00:00,  6.05it/s]
# Train Instance Accuracy: 0.059002
# Epoch 1 (5/5):
# 100% 146/146 [00:25<00:00,  5.77it/s]
# Train Instance Accuracy: 0.052977
