# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Move to work directory
# %cd /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master
# Out:
# /content/drive/MyDrive/THESIS/Pointnet_Pointnet2_pytorch-master

# %% [markdown]
# ## Train PointGuard (using cls samples and shift adversarial attacks)

# %%
# !python train_pointguard.py --model pointnet_pointguard --log_dir pointguard_classification_shift_attack --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, model='pointnet_pointguard', epoch=10, learning_rate=0.001, num_point=16, optimizer='Adam', log_dir='pointguard_classification_shift_attack', decay_rate=0.0001, num_channel=4)
# Load dataset ...
# The size of train data is 9368
# The size of test data is 4016
# Epoch 1 (1/10):
# 100% 146/146 [05:41<00:00,  2.34s/it]
# Train MSE loss: 0.100581
# 100% 63/63 [02:10<00:00,  2.07s/it]
# Test MSE loss: 0.208187
# Best test MSE loss: 0.208187
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 2 (2/10):
# 100% 146/146 [00:29<00:00,  4.87it/s]
# Train MSE loss: 0.069830
# 100% 63/63 [00:11<00:00,  5.69it/s]
# Test MSE loss: 0.201136
# Best test MSE loss: 0.201136
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 3 (3/10):
# 100% 146/146 [00:29<00:00,  4.89it/s]
# Train MSE loss: 0.064551
# 100% 63/63 [00:10<00:00,  5.83it/s]
# Test MSE loss: 0.185874
# Best test MSE loss: 0.185874
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 4 (4/10):
# 100% 146/146 [00:29<00:00,  4.92it/s]
# Train MSE loss: 0.059055
# 100% 63/63 [00:09<00:00,  6.55it/s]
# Test MSE loss: 0.210478
# Best test MSE loss: 0.185874
# Epoch 5 (5/10):
# 100% 146/146 [00:28<00:00,  5.06it/s]
# Train MSE loss: 0.052836
# 100% 63/63 [00:11<00:00,  5.53it/s]
# Test MSE loss: 0.139888
# Best test MSE loss: 0.139888
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 6 (6/10):
# 100% 146/146 [00:31<00:00,  4.70it/s]
# Train MSE loss: 0.048497
# 100% 63/63 [00:11<00:00,  5.63it/s]
# Test MSE loss: 0.187526
# Best test MSE loss: 0.139888
# Epoch 7 (7/10):
# 100% 146/146 [00:31<00:00,  4.59it/s]
# Train MSE loss: 0.047028
# 100% 63/63 [00:10<00:00,  5.95it/s]
# Test MSE loss: 0.134031
# Best test MSE loss: 0.134031
# Saving at log/pointguard/pointguard_classification_shift_attack/epoch_10_npoint_16_bsize_64/checkpoints/best_model.pth
# Epoch 8 (8/10):
# 100% 146/146 [00:31<00:00,  4.65it/s]
# Train MSE loss: 0.043784
# 100% 63/63 [00:11<00:00,  5.71it/s]
# Test MSE loss: 0.157371
# Best test MSE loss: 0.134031
# Epoch 9 (9/10):
# 100% 146/146 [00:30<00:00,  4.78it/s]
# Train MSE loss: 0.041326
# 100% 63/63 [00:11<00:00,  5.37it/s]
# Test MSE loss: 0.170960
# Best test MSE loss: 0.134031
# Epoch 10 (10/10):
# 100% 146/146 [00:29<00:00,  4.91it/s]
# Train MSE loss: 0.039698
# 100% 63/63 [00:09<00:00,  6.75it/s]
# Test MSE loss: 0.169634
# Best test MSE loss: 0.134031

# %%
# !python test_pointguard.py --log_dir pointguard_classification_shift_attack --num_channel 4 --batch_size 64 --epoch 10 --num_point 16
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=64, log_dir='pointguard_classification_shift_attack', num_channel=4, epoch=10, num_point=16)
# Load dataset ...
# The size of test data is 4016
# 100% 63/63 [00:12<00:00,  5.04it/s]
# Test MSE loss: 0.068731
